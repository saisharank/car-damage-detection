# %%
# !git clone https://github.com/googlecodelabs/tensorflow-for-poets-2
# Out:
# Cloning into 'tensorflow-for-poets-2'...
# remote: Enumerating objects: 426, done.
# remote: Total 426 (delta 0), reused 0 (delta 0), pack-reused 426
# Receiving objects: 100% (426/426), 33.97 MiB | 8.88 MiB/s, done.
# Resolving deltas: 100% (159/159), done.

# %%
# %cd tensorflow-for-poets-2
# Out:
# /content/tensorflow-for-poets-2

# %%
# !git clone https://github.com/saisharank/car_location
# Out:
# Cloning into 'car_location'...
# remote: Enumerating objects: 1275, done.
# remote: Counting objects: 100% (1275/1275), done.
# remote: Compressing objects: 100% (1275/1275), done.
# remote: Total 1275 (delta 0), reused 1275 (delta 0), pack-reused 0
# Receiving objects: 100% (1275/1275), 13.51 MiB | 5.67 MiB/s, done.

# %%
mv /content/tensorflow-for-poets-2/car_location /content/tensorflow-for-poets-2/tf_files/

# %%
# !ls tf_files/car_location
# !pwd
# Out:
# front  rear
# /content/tensorflow-for-poets-2

# %%
# !python3 -m scripts.retrain -h
# Out:
# usage: retrain.py [-h] [--image_dir IMAGE_DIR] [--output_graph OUTPUT_GRAPH]
#                   [--intermediate_output_graphs_dir INTERMEDIATE_OUTPUT_GRAPHS_DIR]
#                   [--intermediate_store_frequency INTERMEDIATE_STORE_FREQUENCY]
#                   [--output_labels OUTPUT_LABELS]
#                   [--summaries_dir SUMMARIES_DIR]
#                   [--how_many_training_steps HOW_MANY_TRAINING_STEPS]
#                   [--learning_rate LEARNING_RATE]
#                   [--testing_percentage TESTING_PERCENTAGE]
#                   [--validation_percentage VALIDATION_PERCENTAGE]
#                   [--eval_step_interval EVAL_STEP_INTERVAL]
#                   [--train_batch_size TRAIN_BATCH_SIZE]
#                   [--test_batch_size TEST_BATCH_SIZE]
#                   [--validation_batch_size VALIDATION_BATCH_SIZE]
#                   [--print_misclassified_test_images] [--model_dir MODEL_DIR]
#                   [--bottleneck_dir BOTTLENECK_DIR]
# ...

# %%
# !wget https://bin.equinox.io/c/4VmDzA7iaHb/ngrok-stable-linux-amd64.zip
# !unzip -o ngrok-stable-linux-amd64.zip
# Out:
# --2019-11-13 15:12:35--  https://bin.equinox.io/c/4VmDzA7iaHb/ngrok-stable-linux-amd64.zip
# Resolving bin.equinox.io (bin.equinox.io)... 34.200.84.76, 52.86.84.98, 3.224.23.57, ...
# Connecting to bin.equinox.io (bin.equinox.io)|34.200.84.76|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 13773305 (13M) [application/octet-stream]
# Saving to: ‘ngrok-stable-linux-amd64.zip’
#
# ngrok-stable-linux- 100%[===================>]  13.13M  6.60MB/s    in 2.0s
#
# 2019-11-13 15:12:38 (6.60 MB/s) - ‘ngrok-stable-linux-amd64.zip’ saved [13773305/13773305]
#
# Archive:  ngrok-stable-linux-amd64.zip
#   inflating: ngrok

# %%
# !python3 -m scripts.retrain \
  --bottleneck_dir=tf_files/bottlenecks \
  --how_many_training_steps=500 \
  --model_dir=tf_files/models1/ \
  --summaries_dir=tf_files/training_summaries/"inception_v3" \
  --output_graph=tf_files/retrained_graph1.pb \
  --output_labels=tf_files/retrained_labels1.txt \
  --architecture="inception_v3" \
  --image_dir=tf_files/car_location
# Out:
# WARNING:tensorflow:From /content/tensorflow-for-poets-2/scripts/retrain.py:1326: The name tf.app.run is deprecated. Please use tf.compat.v1.app.run instead.
#
# WARNING:tensorflow:From /content/tensorflow-for-poets-2/scripts/retrain.py:970: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.
#
# W1113 15:12:46.953550 139876370364288 module_wrapper.py:139] From /content/tensorflow-for-poets-2/scripts/retrain.py:970: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.
#
# WARNING:tensorflow:From /content/tensorflow-for-poets-2/scripts/retrain.py:970: The name tf.logging.INFO is deprecated. Please use tf.compat.v1.logging.INFO instead.
#
# W1113 15:12:46.953820 139876370364288 module_wrapper.py:139] From /content/tensorflow-for-poets-2/scripts/retrain.py:970: The name tf.logging.INFO is deprecated. Please use tf.compat.v1.logging.INFO instead.
#
# ...

# %%
model_dir = "tf_files/"
LOG_DIR = model_dir
get_ipython().system_raw(
    'tensorboard --logdir {} --host 0.0.0.0 --port 6006 &'
    .format(LOG_DIR)
)
get_ipython().system_raw('./ngrok http 6006 &')
# !ls {model_dir}
# Out:
# bottlenecks   models1		   retrained_labels1.txt
# car_location  retrained_graph1.pb  training_summaries

# %%
from google.colab import drive
drive.mount('/content/drive')
! curl -s http://localhost:4040/api/tunnels | python3 -c \
    "import sys, json; print(json.load(sys.stdin)['tunnels'][0]['public_url'])"
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive
# http://0512db2f.ngrok.io
